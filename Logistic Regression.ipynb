# %%
# setup
import pandas as pd
import os
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

import MyFunctions as f

# %%
# empty dataset to store the resutls
resultsLR = pd.DataFrame(columns=["model_id", "cost", "f1_score", "presicion", "recall"])

# %%
# import pre-processed test ser
test = pd.read_csv("data/test_set_preprocessed.csv")
y_test = test["class"].values
X_test = test.drop("class", axis=1)

# %%
# Baseline model: No sampling technique, no hyperparameter tunning

# import the relevant train set
train = pd.read_csv("train_after_resample/No resampling.csv")
y_train = train["class"].values
X_train = train.drop("class", axis=1)

# train, predict and evaluate
clf = LogisticRegression(random_state=0, n_jobs=-1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print()
cost, f1s, pres, recall = f.evaluation_metrics(y_pred, y_test, X_test, clf, 10, 500, "Baseline LR")

new_row = {"model_id": "Baseline LR", "cost": cost, "f1_score": f1s, "presicion": pres, "recall":recall}
resultsLR = resultsLR.append(new_row, ignore_index=True)
# Out:
# Total cost: 179970
#
# F1 score 0.041
# Precision:  0.022
# Recall 0.413
#
# False positives:  6997
# False negatives:  220
#
# Confusion matrix, without normalization
#      Normalized confusion matrix

# %%
# parameters grid
parameters_grid = {"penalty":["l1", "l2", "elasticnet", None], 
                   "class_weight":["balanced", None],
                  "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"]}

# %%
# train with all sample tecniques, grid search, score: "recall"
for element in os.listdir("train_after_resample"):
    
    model_id = "LR_"+element[0:-4]+"_recall"
    
    print("\033[1m"+"Sampling Technique:"+"\033[0m", element[0:-4])
    print("\033[1m"+"Classification algorithm:"+"\033[0m", "Logistic Regression")
    print("\033[1m"+"Scoring:"+"\033[0m", "recall")
    
    # import the smapled training set
    sampled_train = pd.read_csv("train_after_resample/"+element)
    y_sam_train = sampled_train["class"].values
    X_sam_train = sampled_train.drop("class", axis=1)
    
    # set classifier
    lr = LogisticRegression(random_state=0, n_jobs=-1, max_iter=1000)
    clf = GridSearchCV(estimator=lr, param_grid=parameters_grid, scoring="recall", n_jobs=-1, refit=True, error_score=0)
    
    # fit
    clf.fit(X_sam_train, y_sam_train)
    
    # predict
    y_pred = clf.predict(X_test)
    
    # show best parameters (used in final training)
    print("Best parameters set found on development set:")
    print(clf.best_params_)
    print()
    
    # evaluate
    print("\033[1m"+"Model evaluation"+"\033[0m")
    print()
    cost, f1s, pres, recall = f.evaluation_metrics(y_pred, y_test, X_test, clf, 10, 500, model_id)
    
    # save evaluation metrics in dataframe
    new_row = {"model_id": model_id, "cost": cost, "f1_score": f1s, "presicion": pres, "recall":recall}
    resultsLR = resultsLR.append(new_row, ignore_index=True)
# Out:
# Sampling Technique: ADASYN
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 113680
#
# F1 score 0.062
# Precision:  0.032
# Recall 0.995
#
# False positives:  11268
# False negatives:  2
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Border Line SMOTE 1
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 117290
#
# F1 score 0.06
# Precision:  0.031
# Recall 0.995
#
# False positives:  11629
# False negatives:  2
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Border Line SMOTE 2
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 117670
#
# F1 score 0.06
# Precision:  0.031
# Recall 0.995
#
# False positives:  11667
# False negatives:  2
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Cluster Centroids
# Classification algorithm: Logistic Regression
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'lbfgs'}
#
# Model evaluation
#
# Total cost: 122530
#
# F1 score 0.059
# Precision:  0.031
# Recall 0.947
#
# False positives:  11253
# False negatives:  20
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Edited Nearest Neighbours
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 117380
#
# F1 score 0.06
# Precision:  0.031
# Recall 0.995
#
# False positives:  11638
# False negatives:  2
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Instance Hardness Threshold
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'liblinear'}
#
# Model evaluation
#
# Total cost: 149390
#
# F1 score 0.051
# Precision:  0.026
# Recall 0.776
#
# False positives:  10739
# False negatives:  84
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: k-Means SMOTE
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 187220
#
# F1 score 0.038
# Precision:  0.02
# Recall 0.429
#
# False positives:  8022
# False negatives:  214
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: NearMiss
# Classification algorithm: Logistic Regression
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'lbfgs'}
#
# Model evaluation
#
# Total cost: 124420
#
# F1 score 0.059
# Precision:  0.03
# Recall 0.939
#
# False positives:  11292
# False negatives:  23
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: No resampling
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 117520
#
# F1 score 0.06
# Precision:  0.031
# Recall 0.995
#
# False positives:  11652
# False negatives:  2
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: OneSidedSelection
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 118480
#
# F1 score 0.06
# Precision:  0.031
# Recall 0.995
#
# False positives:  11748
# False negatives:  2
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Random Over-Sampler
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 118550
#
# F1 score 0.06
# Precision:  0.031
# Recall 0.995
#
# False positives:  11755
# False negatives:  2
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Random Under-Sampler
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 118870
#
# F1 score 0.06
# Precision:  0.031
# Recall 0.992
#
# False positives:  11737
# False negatives:  3
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SMOTE and cleaning using ENN
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 114210
#
# F1 score 0.062
# Precision:  0.032
# Recall 0.995
#
# False positives:  11321
# False negatives:  2
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SMOTE and cleaning using Tomek links
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 115880
#
# F1 score 0.061
# Precision:  0.031
# Recall 0.995
#
# False positives:  11488
# False negatives:  2
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SMOTE
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 116530
#
# F1 score 0.061
# Precision:  0.031
# Recall 0.995
#
# False positives:  11553
# False negatives:  2
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SVM SMOTE
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'sag'}
#
# Model evaluation
#
# Total cost: 118320
#
# F1 score 0.06
# Precision:  0.031
# Recall 0.997
#
# False positives:  11782
# False negatives:  1
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Tomek Links
# Classification algorithm: Logistic Regression
# Scoring: recall
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}
#
# Model evaluation
#
# Total cost: 118450
#
# F1 score 0.06
# Precision:  0.031
# Recall 0.995
#
# False positives:  11745
# False negatives:  2
#
# Confusion matrix, without normalization
#      Normalized confusion matrix

# %%
# train with all sample tecniques, grid search, score: "roc_auc"
for element in os.listdir("train_after_resample"):
    
    model_id = "LR_"+element[0:-4]+"_roc_auc"

    print("\033[1m"+"Sampling Technique:"+"\033[0m", element[0:-4])
    print("\033[1m"+"Classification algorithm:"+"\033[0m", "Logistic Regression")
    print("\033[1m"+"Scoring:"+"\033[0m", "roc_auc")
    
    # import the smapled training set
    sampled_train = pd.read_csv("train_after_resample/"+element)
    y_sam_train = sampled_train["class"].values
    X_sam_train = sampled_train.drop("class", axis=1)
    
    # set classifier
    lr = LogisticRegression(random_state=0, n_jobs=-1, max_iter=1000)
    clf = GridSearchCV(estimator=lr, param_grid=parameters_grid, scoring="roc_auc", n_jobs=-1, refit=True, error_score=0)
    
    # fit
    clf.fit(X_sam_train, y_sam_train)
    
    # predict
    y_pred = clf.predict(X_test)
    
    # show best parameters (used in final training)
    print("Best parameters set found on development set:")
    print(clf.best_params_)
    print()
    
    # evaluate
    print("\033[1m"+"Model evaluation"+"\033[0m")
    print()
    cost, f1s, pres, recall = f.evaluation_metrics(y_pred, y_test, X_test, clf, 10, 500, model_id)
    
    # save evaluation metrics in dataframe
    new_row = {"model_id": model_id, "cost": cost, "f1_score": f1s, "presicion": pres, "recall":recall}
    resultsLR = resultsLR.append(new_row, ignore_index=True)
# Out:
# Sampling Technique: ADASYN
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# Best parameters set found on development set:
# {'class_weight': None, 'penalty': 'l1', 'solver': 'liblinear'}
#
# Model evaluation
#
# Total cost: 58080
#
# F1 score 0.164
# Precision:  0.09
# Recall 0.864
#
# False positives:  3258
# False negatives:  51
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Border Line SMOTE 1
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'newton-cg'}
#
# Model evaluation
#
# Total cost: 57330
#
# F1 score 0.17
# Precision:  0.095
# Recall 0.859
#
# False positives:  3083
# False negatives:  53
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Border Line SMOTE 2
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'newton-cg'}
#
# Model evaluation
#
# Total cost: 58610
#
# F1 score 0.166
# Precision:  0.092
# Recall 0.856
#
# False positives:  3161
# False negatives:  54
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Cluster Centroids
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'newton-cg'}
#
# Model evaluation
#
# Total cost: 56100
#
# F1 score 0.189
# Precision:  0.106
# Recall 0.843
#
# False positives:  2660
# False negatives:  59
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Edited Nearest Neighbours
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'newton-cg'}
#
# Model evaluation
#
# Total cost: 56920
#
# F1 score 0.167
# Precision:  0.092
# Recall 0.867
#
# False positives:  3192
# False negatives:  50
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Instance Hardness Threshold
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'liblinear'}
#
# Model evaluation
#
# Total cost: 54910
#
# F1 score 0.176
# Precision:  0.098
# Recall 0.867
#
# False positives:  2991
# False negatives:  50
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: k-Means SMOTE
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'liblinear'}
#
# Model evaluation
#
# Total cost: 67400
#
# F1 score 0.197
# Precision:  0.113
# Recall 0.76
#
# False positives:  2240
# False negatives:  90
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: NearMiss
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'newton-cg'}
#
# Model evaluation
#
# Total cost: 55810
#
# F1 score 0.19
# Precision:  0.107
# Recall 0.843
#
# False positives:  2631
# False negatives:  59
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: No resampling
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'liblinear'}
#
# Model evaluation
#
# Total cost: 56240
#
# F1 score 0.172
# Precision:  0.095
# Recall 0.864
#
# False positives:  3074
# False negatives:  51
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: OneSidedSelection
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'liblinear'}
#
# Model evaluation
#
# Total cost: 56960
#
# F1 score 0.17
# Precision:  0.094
# Recall 0.861
#
# False positives:  3096
# False negatives:  52
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Random Over-Sampler
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'newton-cg'}
#
# Model evaluation
#
# Total cost: 56260
#
# F1 score 0.172
# Precision:  0.095
# Recall 0.864
#
# False positives:  3076
# False negatives:  51
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Random Under-Sampler
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'liblinear'}
#
# Model evaluation
#
# Total cost: 55700
#
# F1 score 0.171
# Precision:  0.095
# Recall 0.869
#
# False positives:  3120
# False negatives:  49
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SMOTE and cleaning using ENN
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': None, 'penalty': 'l2', 'solver': 'newton-cg'}
#
# Model evaluation
#
# Total cost: 58990
#
# F1 score 0.162
# Precision:  0.089
# Recall 0.861
#
# False positives:  3299
# False negatives:  52
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SMOTE and cleaning using Tomek links
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': None, 'penalty': 'l2', 'solver': 'newton-cg'}
#
# Model evaluation
#
# Total cost: 57540
#
# F1 score 0.169
# Precision:  0.094
# Recall 0.859
#
# False positives:  3104
# False negatives:  53
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SMOTE
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'newton-cg'}
#
# Model evaluation
#
# Total cost: 57530
#
# F1 score 0.169
# Precision:  0.094
# Recall 0.859
#
# False positives:  3103
# False negatives:  53
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SVM SMOTE
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'liblinear'}
#
# Model evaluation
#
# Total cost: 58750
#
# F1 score 0.175
# Precision:  0.098
# Recall 0.843
#
# False positives:  2925
# False negatives:  59
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Tomek Links
# Classification algorithm: Logistic Regression
# Scoring: roc_auc
# C:\Users\falli\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1355: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# Best parameters set found on development set:
# {'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'liblinear'}
#
# Model evaluation
#
# Total cost: 56520
#
# F1 score 0.17
# Precision:  0.095
# Recall 0.864
#
# False positives:  3102
# False negatives:  51
#
# Confusion matrix, without normalization
#      Normalized confusion matrix

# %%
resultsLR.head()
# Out:
#                         model_id    cost  f1_score  presicion    recall
# 0                    Baseline LR  179970  0.041185   0.021672  0.413333
# 1               LR_ADASYN_recall  113680  0.062084   0.032042  0.994667
# 2  LR_Border Line SMOTE 1_recall  117290  0.060273   0.031078  0.994667
# 3  LR_Border Line SMOTE 2_recall  117670  0.060089   0.030980  0.994667
# 4    LR_Cluster Centroids_recall  122530  0.059251   0.030582  0.946667

# %%
resultsLR.to_csv("results/LR.csv", index=False)
