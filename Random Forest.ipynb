# %%
# setup
import pandas as pd
import os
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

import MyFunctions as f

# %%
# empty dataset to store the resutls
resultsRF = pd.DataFrame(columns=["model_id", "cost", "f1_score", "presicion", "recall"])

# %%
# import pre-processed test ser
test = pd.read_csv("data/test_set_preprocessed.csv")
y_test = test["class"].values
X_test = test.drop("class", axis=1)

# %%
# Baseline model: No sampling technique, no hyperparameter tunning

# import the relevant train set
train = pd.read_csv("train_after_resample/No resampling.csv")
y_train = train["class"].values
X_train = train.drop("class", axis=1)

# train, predict and evaluate
clf = RandomForestClassifier(random_state=0, n_jobs=-1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print()
cost, f1s, pres, recall = f.evaluation_metrics(y_pred, y_test, X_test, clf, 10, 500, "Baseline RF")

new_row = {"model_id": "Baseline RF", "cost": cost, "f1_score": f1s, "presicion": pres, "recall":recall}
resultsRF = resultsRF.append(new_row, ignore_index=True)
# Out:
# Total cost: 122330
#
# F1 score 0.129
# Precision:  0.075
# Recall 0.461
#
# False positives:  2133
# False negatives:  202
#
# Confusion matrix, without normalization
#      Normalized confusion matrix

# %%
# parameters grid
parameters_grid = {"class_weight": [None, "balanced", "balanced_subsample"]}

# %%
# train with all sample tecniques, grid search, score: "recall"
for element in os.listdir("train_after_resample"):
    
    model_id = "RF_"+element[0:-4]+"_recall"
    
    print("\033[1m"+"Sampling Technique:"+"\033[0m", element[0:-4])
    print("\033[1m"+"Classification algorithm:"+"\033[0m", "Random Forest")
    print("\033[1m"+"Scoring:"+"\033[0m", "recall")
    
    # import the smapled training set
    sampled_train = pd.read_csv("train_after_resample/"+element)
    y_sam_train = sampled_train["class"].values
    X_sam_train = sampled_train.drop("class", axis=1)
    
    # set classifier
    rf = RandomForestClassifier(random_state=0, n_jobs=-1)
    clf = GridSearchCV(estimator=rf, param_grid=parameters_grid, scoring="recall", n_jobs=-1, refit=True, error_score=0)
    
    # fit
    clf.fit(X_sam_train, y_sam_train)
    
    # predict
    y_pred = clf.predict(X_test)
    
    # show best parameters (used in final training)
    print("Best parameters set found on development set:")
    print(clf.best_params_)
    print()
    
    # evaluate
    print("\033[1m"+"Model evaluation"+"\033[0m")
    print()
    cost, f1s, pres, recall = f.evaluation_metrics(y_pred, y_test, X_test, clf, 10, 500, model_id)
    
    # save evaluation metrics in dataframe
    new_row = {"model_id": model_id, "cost": cost, "f1_score": f1s, "presicion": pres, "recall":recall}
    resultsRF = resultsRF.append(new_row, ignore_index=True)
# Out:
# Sampling Technique: ADASYN
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': 'balanced'}
#
# Model evaluation
#
# Total cost: 147380
#
# F1 score 0.13
# Precision:  0.086
# Recall 0.272
#
# False positives:  1088
# False negatives:  273
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Border Line SMOTE 1
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 158460
#
# F1 score 0.116
# Precision:  0.081
# Recall 0.2
#
# False positives:  846
# False negatives:  300
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Border Line SMOTE 2
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 149690
#
# F1 score 0.132
# Precision:  0.089
# Recall 0.253
#
# False positives:  969
# False negatives:  280
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Cluster Centroids
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 158730
#
# F1 score 0.045
# Precision:  0.023
# Recall 0.979
#
# False positives:  15473
# False negatives:  8
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Edited Nearest Neighbours
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 104260
#
# F1 score 0.15
# Precision:  0.087
# Recall 0.563
#
# False positives:  2226
# False negatives:  164
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Instance Hardness Threshold
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 165340
#
# F1 score 0.044
# Precision:  0.022
# Recall 0.944
#
# False positives:  15484
# False negatives:  21
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: k-Means SMOTE
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 113530
#
# F1 score 0.142
# Precision:  0.083
# Recall 0.507
#
# False positives:  2103
# False negatives:  185
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: NearMiss
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 152010
#
# F1 score 0.048
# Precision:  0.025
# Recall 0.872
#
# False positives:  12801
# False negatives:  48
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: No resampling
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 122330
#
# F1 score 0.129
# Precision:  0.075
# Recall 0.461
#
# False positives:  2133
# False negatives:  202
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: OneSidedSelection
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 120390
#
# F1 score 0.132
# Precision:  0.076
# Recall 0.472
#
# False positives:  2139
# False negatives:  198
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Random Over-Sampler
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 174340
#
# F1 score 0.073
# Precision:  0.055
# Recall 0.107
#
# False positives:  684
# False negatives:  335
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Random Under-Sampler
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 46590
#
# F1 score 0.188
# Precision:  0.105
# Recall 0.907
#
# False positives:  2909
# False negatives:  35
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SMOTE and cleaning using ENN
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 128700
#
# F1 score 0.16
# Precision:  0.101
# Recall 0.381
#
# False positives:  1270
# False negatives:  232
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SMOTE and cleaning using Tomek links
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': 'balanced'}
#
# Model evaluation
#
# Total cost: 147740
#
# F1 score 0.125
# Precision:  0.081
# Recall 0.275
#
# False positives:  1174
# False negatives:  272
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SMOTE
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 145570
#
# F1 score 0.118
# Precision:  0.074
# Recall 0.299
#
# False positives:  1407
# False negatives:  263
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SVM SMOTE
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 131260
#
# F1 score 0.112
# Precision:  0.065
# Recall 0.421
#
# False positives:  2276
# False negatives:  217
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Tomek Links
# Classification algorithm: Random Forest
# Scoring: recall
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 115450
#
# F1 score 0.138
# Precision:  0.08
# Recall 0.499
#
# False positives:  2145
# False negatives:  188
#
# Confusion matrix, without normalization
#      Normalized confusion matrix

# %%
# train with all sample tecniques, grid search, score: "roc_auc"
for element in os.listdir("train_after_resample"):
    
    model_id = "RF_"+element[0:-4]+"_roc_auc"

    print("\033[1m"+"Sampling Technique:"+"\033[0m", element[0:-4])
    print("\033[1m"+"Classification algorithm:"+"\033[0m", "Random Forest")
    print("\033[1m"+"Scoring:"+"\033[0m", "roc_auc")
    
    # import the smapled training set
    sampled_train = pd.read_csv("train_after_resample/"+element)
    y_sam_train = sampled_train["class"].values
    X_sam_train = sampled_train.drop("class", axis=1)
    
    # set classifier
    rf = RandomForestClassifier(random_state=0, n_jobs=-1)
    clf = GridSearchCV(estimator=rf, param_grid=parameters_grid, scoring="roc_auc", n_jobs=-1, refit=True, error_score=0)
    
    # fit
    clf.fit(X_sam_train, y_sam_train)
    
    # predict
    y_pred = clf.predict(X_test)
    
    # show best parameters (used in final training)
    print("Best parameters set found on development set:")
    print(clf.best_params_)
    print()
    
    # evaluate
    print("\033[1m"+"Model evaluation"+"\033[0m")
    print()
    cost, f1s, pres, recall = f.evaluation_metrics(y_pred, y_test, X_test, clf, 10, 500, model_id)
    
    # save evaluation metrics in dataframe
    new_row = {"model_id": model_id, "cost": cost, "f1_score": f1s, "presicion": pres, "recall":recall}
    resultsRF = resultsRF.append(new_row, ignore_index=True)
# Out:
# Sampling Technique: ADASYN
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced'}
#
# Model evaluation
#
# Total cost: 147380
#
# F1 score 0.13
# Precision:  0.086
# Recall 0.272
#
# False positives:  1088
# False negatives:  273
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Border Line SMOTE 1
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 158460
#
# F1 score 0.116
# Precision:  0.081
# Recall 0.2
#
# False positives:  846
# False negatives:  300
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Border Line SMOTE 2
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 149690
#
# F1 score 0.132
# Precision:  0.089
# Recall 0.253
#
# False positives:  969
# False negatives:  280
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Cluster Centroids
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 158730
#
# F1 score 0.045
# Precision:  0.023
# Recall 0.979
#
# False positives:  15473
# False negatives:  8
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Edited Nearest Neighbours
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 174540
#
# F1 score 0.11
# Precision:  0.212
# Recall 0.075
#
# False positives:  104
# False negatives:  347
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Instance Hardness Threshold
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 165340
#
# F1 score 0.044
# Precision:  0.022
# Recall 0.944
#
# False positives:  15484
# False negatives:  21
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: k-Means SMOTE
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 129260
#
# F1 score 0.12
# Precision:  0.07
# Recall 0.424
#
# False positives:  2126
# False negatives:  216
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: NearMiss
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 152010
#
# F1 score 0.048
# Precision:  0.025
# Recall 0.872
#
# False positives:  12801
# False negatives:  48
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: No resampling
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 182950
#
# F1 score 0.043
# Precision:  0.035
# Recall 0.053
#
# False positives:  545
# False negatives:  355
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: OneSidedSelection
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 176340
#
# F1 score 0.099
# Precision:  0.222
# Recall 0.064
#
# False positives:  84
# False negatives:  351
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Random Over-Sampler
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 179060
#
# F1 score 0.056
# Precision:  0.042
# Recall 0.083
#
# False positives:  706
# False negatives:  344
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Random Under-Sampler
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 46590
#
# F1 score 0.188
# Precision:  0.105
# Recall 0.907
#
# False positives:  2909
# False negatives:  35
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SMOTE and cleaning using ENN
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 128700
#
# F1 score 0.16
# Precision:  0.101
# Recall 0.381
#
# False positives:  1270
# False negatives:  232
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SMOTE and cleaning using Tomek links
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 155310
#
# F1 score 0.109
# Precision:  0.071
# Recall 0.232
#
# False positives:  1131
# False negatives:  288
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SMOTE
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 145570
#
# F1 score 0.118
# Precision:  0.074
# Recall 0.299
#
# False positives:  1407
# False negatives:  263
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: SVM SMOTE
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': 'balanced_subsample'}
#
# Model evaluation
#
# Total cost: 131260
#
# F1 score 0.112
# Precision:  0.065
# Recall 0.421
#
# False positives:  2276
# False negatives:  217
#
# Confusion matrix, without normalization
#      Normalized confusion matrix
# Sampling Technique: Tomek Links
# Classification algorithm: Random Forest
# Scoring: roc_auc
# Best parameters set found on development set:
# {'class_weight': None}
#
# Model evaluation
#
# Total cost: 115450
#
# F1 score 0.138
# Precision:  0.08
# Recall 0.499
#
# False positives:  2145
# False negatives:  188
#
# Confusion matrix, without normalization
#      Normalized confusion matrix

# %%
resultsRF.head()
# Out:
#                         model_id    cost  f1_score  presicion    recall
# 0                    Baseline RF  122330  0.129056   0.075022  0.461333
# 1               RF_ADASYN_recall  147380  0.130351   0.085714  0.272000
# 2  RF_Border Line SMOTE 1_recall  158460  0.115741   0.081433  0.200000
# 3  RF_Border Line SMOTE 2_recall  149690  0.132036   0.089286  0.253333
# 4    RF_Cluster Centroids_recall  158730  0.045267   0.023169  0.978667

# %%
resultsRF.to_csv("results/RF.csv", index=False)
